# %%
# if statement
cars = ['audi','toyota','suzuki','bmw']
for car in cars:
    if car == 'bmw':
        print(car.upper())
    else:
        print(car.title())
#  "="means state
# "=="means ask

gay = "girl"
if gay != "man":
    print("you are a lily")

digit = 13
print("Your number is: " + str(digit))
if digit == 13:
    print("Yes")
else:
    print("No")
if digit != 21:
    print("Damn,it is incorrect.")
if digit < 10:
    print("it is lower than 10")
else:
    print("it is greater than 10")
    
num = 99
if (num <= 100)and(num == 99):
    print("True")
if(num == 88)or(num == 99):
    print("True")

# Check some known value
banned_users = ['Andrew','Huawei','Xiaomi','Apple']
user = 'Sumsang'
if user not in banned_users:
    print(user.title() + ",you can post a response if you wish")

# Practice
car = "subaru"
if car == "subaru":
    print("\nIs car == 'subaru'? I predict True.")
print("\nIs car == 'audi'? I don't think so.")

statement1 = "I am gay"
statement2 = "I am lily"
if statement1 == statement2:
    print("\nYou are a doule sex guy")
else:
    print("\nYou are a single sex guy")

check1 = "cat"
check2 = "Cat"
if check1.lower() == check2.lower():
    print("\nThey are equal.")
else:
    print("\nThey are different.")
math1 = 9
math2 = -1
print("Your math is: " + str(math1) + " and " + str(math2) + ".")
if math1 == math2:
    print("They are equal.")
if math1 != math2:
    print("They are not equal.")
if math1 >= math2:
    print("math1 greater than or equal to math2.")
else:
    print("math1 smaller than math2.")
math3 = -1
list = [1,2,3,4]
if math3 not in list:
    print("-1 is not the natural number")
# Out:
# Audi
# Toyota
# Suzuki
# BMW
# you are a lily
# Your number is: 13
# Yes
# Damn,it is incorrect.
# it is greater than 10
# True
# True
# Sumsang,you can post a response if you wish
#
# Is car== 'subaru'? I predict True.
#
# Is car == 'audi'? I don't think so.
#
# You are a single sex guy
#
# They are equal.
# Your math is: 9 and -1.
# They are not equal.
# math1 greater than or equal to math2.
# -1 is not the natural number

# %%
age = 12
if age < 4:
    print("Your admission is $0.")
elif (age >= 4) and(age < 18):
    print("Your admission is $5.")
else:
    print("Your admission is $10.")

# Advance version(simplified)
age = 12
if age < 4:
    fee = 0
elif age < 18:
    fee = 5
else:
    fee = 10
print("Your admission is $" + str(fee) + ".")

# Muti-else if statement
age = 99
if age < 4:
    price = 0
elif age < 18:
    price = 5
elif age < 65:
    price = 10
else:
    price = 9
print("Your admission is $" + str(price) + ".")
# Out:
# Your admission is $5.
# Your admission is $5.
# Your admission is $9.

# %%
requested_toppings = ['mushrooms','extra cheese']
if "mushrooms" in requested_toppings:
    print("Adding mushrooms.")
if 'pepperoni' in requested_toppings:
    print("Adding pepperoni")
if 'extra cheese' in requested_toppings:
    print("Adding extra cheese")
print("Finished making your pizza!")

# Practice
alien_color = "green"
if alien_color == "green":
    print("You got 5 point!")
elif alien_color == "red":
    print("You got 10 point!")
elif alien_color == "yellow":
    print("You got 15 point!")

age = 5
if age < 2:
    print("He is a baby.")
elif (age == 2)or(age < 4):
    print("He is learning walking now.")
elif(age == 4)or(age < 13):
    print("He is a child")
elif(age == 13)or(age < 20):
    print("He is a teenager")
elif(age == 20)or(age < 65):
    print("He is a adult")
elif age >= 65:
    print("He is a old man")

favourite_fruits = ['Banana','Pineapple','Watermelon']
if 'Banana' in favourite_fruits:
    print("You really like banana!")
# Out:
# Adding mushrooms.
# Adding extra cheese
# Finished making your pizza!
# You got 5 point!
# He is a child
# You really like banana!

# %%
requested_toppings = ['mushrooms','green peppers','extra cheese']
if requested_toppings:    # Checking whether it is empty or not.
    for requested_topping in requested_toppings:
        if requested_topping == 'green peppers':
            print("Sorry,we are out of green peppers right now.")
        else:
            print("Are you sure you want to a plain pizza?")
print("\nFinished making your pizza\n")

# Muti-list
available_toppings = ['mushrooms','olives','green peppers','pepperoni','pineapple','extra cheese']
requested_toppings = ['mushrooms','french fries','extra cheese']
for requested_topping in requested_toppings:
    if requested_topping in available_toppings:
        print("Adding " + requested_topping + ".")
    else:
        print("Sorry,we dont have " + requested_topping + ".")

# Practice
print("\n")
names = ['Andy','Admin','Gaye','Martin','Poon']
if names:  # Check whether it is empty or not.
    for name in names:
        if name == "Admin":
            print("Hello Admin,would you like to see a status report?")
        else:
            print("Hello " + name + ",thank you for logging in again.")
else:
    print("We need to find some users.")

print("\n")
current_users = ['A','B','C','D','E']
new_users = ['Ailen','Biden','C','D','Edison']
for new_user in new_users:
    if new_user in current_users:
        print("You should enter other users' name")
    else:
        print(new_user + ",this user is not used yet.")

print("\n")
for math in range(1,10):
    if math == 1:                # You should use double space in their both sides when using the "==","<=" and ">=".
        print(str(math) + "st")
    elif math == 2:
        print(str(math) + "nd")
    elif math == 3:
        print(str(math) + "rd")
    else:
        print(str(math) + "th")
# Out:
# Are you sure you want to a plain pizza?
# Sorry,we are out of green peppers right now.
# Are you sure you want to a plain pizza?
#
# Finished making your pizza
#
# Adding mushrooms.
# Sorry,we dont have french fries.
# Adding extra cheese.
#
#
# Hello Andy,thank you for logging in again.
# Hello Admin,would you like to see a status report?
# Hello Gaye,thank you for logging in again.
# Hello Martin,thank you for logging in again.
# Hello Poon,thank you for logging in again.
#
#
# Ailen,this user is not used yet.
# Biden,this user is not used yet.
# You should enter other users' name
# You should enter other users' name
# Edison,this user is not used yet.
#
#
# 1st
# 2nd
# 3rd
# 4th
# 5th
# 6th
# 7th
# 8th
# 9th
